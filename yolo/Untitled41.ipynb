# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jqnLmqWdCNIhvGjaFlAu")
project = rf.workspace("kirill-sergeev").project("vin-detection")
dataset = project.version(7).download("yolov8")

# %%
from google.colab import drive
drive.mount('/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-6c21181b7660> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     127   )
#     128   if ephemeral:
# --> 129     _message.blocking_request(
#     130         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     131     )
#
# ...

# %%
# !ls /drive/MyDrive/Ai
# Out:
#  input	 modal	 output  'Roboflow YOLOv8.ipynb'  'Vin detection.v7i.yolov8.zip'

# %%
# !mkdir dataset

# %%
# !unzip /drive/MyDrive/Ai/'Vin detection.v7i.yolov8.zip' -d /dataset
# Out:
# Выходные данные были обрезаны до нескольких последних строк (5000).
#  extracting: /dataset/train/images/image_141_jpg.rf.39816db81158f885276ae606ec6b3f35.jpg
#  extracting: /dataset/train/images/image_142_jpg.rf.95ebb827c752b3ade94ece0f278dd786.jpg
#  extracting: /dataset/train/images/image_143_jpg.rf.87993ea2bb3c639cd6a4e10d1657cea4.jpg
#  extracting: /dataset/train/images/image_144_jpg.rf.4e69ec21ec83295e069008e627304457.jpg
#  extracting: /dataset/train/images/image_145_jpg.rf.71a3b33d02a69d3631e1e2e67853a2f7.jpg
#  extracting: /dataset/train/images/image_146_jpg.rf.7d52643e80710a454d50f773fbc58608.jpg
#  extracting: /dataset/train/images/image_147_jpg.rf.4b73eda944820b370ce18d95c22558cf.jpg
#  extracting: /dataset/train/images/image_148_jpg.rf.4888b51a0c9b5695b2212c9ec0692c1c.jpg
#  extracting: /dataset/train/images/image_149_jpg.rf.0c41e6f1138685adfb0d8523a25035b2.jpg
#  extracting: /dataset/train/images/image_14_jpg.rf.b7b6729485b36b15672c3a7b12fb53c0.jpg
# ...

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %%
# !ls -l /dataset/
# Out:
# total 24
# -rw-r--r-- 1 root root  260 Feb 14  2023 data.yaml
# -rw-r--r-- 1 root root  144 Feb 14  2023 README.dataset.txt
# -rw-r--r-- 1 root root 1017 Feb 14  2023 README.roboflow.txt
# drwxr-xr-x 4 root root 4096 Feb 14  2023 test
# drwxr-xr-x 4 root root 4096 Feb 14  2023 train
# drwxr-xr-x 4 root root 4096 Feb 14  2023 valid

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data=/dataset/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# [Errno 2] No such file or directory: '{HOME}'
# /content
# ...
# 100% 21.5M/21.5M [00:00<00:00, 211MB/s]
# New https://pypi.org/project/ultralytics/8.1.19 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls runs/detect/train/
# Out:
# args.yaml					    R_curve.png		 val_batch0_labels.jpg
# confusion_matrix_normalized.png			    results.csv		 val_batch0_pred.jpg
# confusion_matrix.png				    results.png		 val_batch1_labels.jpg
# events.out.tfevents.1709185532.80e43e444021.3506.0  train_batch0.jpg	 val_batch1_pred.jpg
# F1_curve.png					    train_batch1.jpg	 val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch2625.jpg  val_batch2_pred.jpg
# labels.jpg					    train_batch2626.jpg  weights
# P_curve.png					    train_batch2627.jpg
# PR_curve.png					    train_batch2.jpg

# %%
# !zip -r runs.zip runs/
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: runs/detect/train/labels.jpg (deflated 29%)
#   adding: runs/detect/train/args.yaml (deflated 51%)
#   adding: runs/detect/train/val_batch2_labels.jpg (deflated 12%)
#   adding: runs/detect/train/labels_correlogram.jpg (deflated 35%)
#   adding: runs/detect/train/PR_curve.png (deflated 30%)
#   adding: runs/detect/train/train_batch2627.jpg (deflated 8%)
#   adding: runs/detect/train/train_batch2.jpg (deflated 4%)
#   adding: runs/detect/train/F1_curve.png (deflated 19%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 3%)
#   adding: runs/detect/train/P_curve.png (deflated 26%)
#   adding: runs/detect/train/events.out.tfevents.1709185532.80e43e444021.3506.0 (deflated 79%)
#   adding: runs/detect/train/val_batch1_pred.jpg (deflated 10%)
# ...

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-524deea5-4f81-49bb-8d19-d92c64528e7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-524deea5-4f81-49bb-8d19-d92c64528e7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !yolo task=detect mode=predict model=yolov8s.pt data=/content/image_1445_jpg.rf.c4081f1234efc17e83a09c3670573e18.jpg
# Out:
# WARNING ⚠️ 'source' is missing. Using default 'source=/usr/local/lib/python3.10/dist-packages/ultralytics/assets'.
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/bus.jpg: 640x480 4 persons, 1 bus, 92.9ms
# image 2/2 /usr/local/lib/python3.10/dist-packages/ultralytics/assets/zidane.jpg: 384x640 2 persons, 1 tie, 70.8ms
# Speed: 8.3ms preprocess, 81.9ms inference, 353.1ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
